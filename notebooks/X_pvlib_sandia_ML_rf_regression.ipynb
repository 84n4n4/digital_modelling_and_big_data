# %%
the target in the feature variablesimport pandas
import matplotlib.pyplot as plt

# %%
df = pandas.read_csv('../data/pv_sandia/pv_sandia_modules.csv')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Vintage', 'Area', 'Material', 'Cells_in_Series',
#        'Parallel_Strings', 'Isco', 'Voco', 'Impo', 'Vmpo', 'Aisc', 'Aimp',
#        'C0', 'C1', 'Bvoco', 'Mbvoc', 'Bvmpo', 'Mbvmp', 'N', 'C2', 'C3', 'A0',
#        'A1', 'A2', 'A3', 'A4', 'B0', 'B1', 'B2', 'B3', 'B4', 'B5', 'DTC', 'FD',
#        'A', 'B', 'C4', 'C5', 'IXO', 'IXXO', 'C6', 'C7', 'Notes', 'name',
#        'annual_energy_yield'],
#       dtype='object')

# %%
df = df.dropna()
df
# Out:
#      Unnamed: 0   Vintage   Area Material  Cells_in_Series  Parallel_Strings  \
# 0             0      2006  1.312    mc-Si               72                 1
# 1             1      2008  1.646    mc-Si               60                 1
# 2             2      2009  1.646    mc-Si               60                 1
# 3             3  2007 (E)  1.280     c-Si               72                 1
# 4             4  2007 (E)  1.280     c-Si               72                 1
# ..          ...       ...    ...      ...              ...               ...
# 508         508      2008  1.700    mc-Si               60                 1
# 509         509  2008 (E)  1.700    mc-Si               60                 1
# 510         510      2009  1.634    mc-Si               60                 1
# 511         511  2009 (E)  1.634    mc-Si               60                 1
# 512         512  2008 (E)  1.700    mc-Si               60                 1
#
#       Isco    Voco   Impo    Vmpo  ...        B      C4      C5     IXO  \
# 0    5.564  42.832  5.028  32.410  ... -0.11610  0.9974  0.0026  5.5400
# 1    8.340  35.310  7.490  27.610  ... -0.07700  0.9720  0.0280  8.2500
# 2    8.490  35.920  7.740  27.920  ... -0.08700  0.9890  0.0120  8.4900
# 3    5.100  43.500  4.550  35.600  ... -0.07500  0.9950  0.0050  5.0400
# 4    5.200  43.600  4.650  35.800  ... -0.07500  0.9950  0.0050  5.1400
# ..     ...     ...    ...     ...  ...      ...     ...     ...     ...
# 508  8.163  36.871  7.388  28.633  ... -0.10120  0.9892  0.0108  8.0491
# 509  8.100  36.600  7.400  30.000  ... -0.10120  0.9892  0.0108  8.2900
# 510  8.222  37.280  7.727  29.886  ... -0.09143  0.9950  0.0050  8.1509
# 511  8.400  37.000  7.800  29.500  ... -0.09143  0.9950  0.0050  8.3100
# 512  7.800  36.000  7.200  29.500  ... -0.07200  0.9850  0.0150  7.6500
#
#        IXXO      C6      C7  \
# 0    3.5600  1.1730 -0.1730
# 1    5.2000  1.0670 -0.0670
# 2    5.4500  1.1370 -0.1370
# 3    3.1600  1.1500 -0.1500
# 4    3.2500  1.1500 -0.1500
# ..      ...     ...     ...
# 508  5.1339  1.1335 -0.1335
# 509  5.1339  1.1335 -0.1335
# 510  5.5099  1.1325 -0.1325
# 511  5.5700  1.1325 -0.1325
# 512  5.0600  1.1130 -0.1130
#
#                                                  Notes  \
# 0    Source: Sandia National Laboratories Updated 9...
# 1    Source: Sandia National Laboratories Updated 9...
# 2    Source: Sandia National Laboratories Updated 9...
# 3    Source: Sandia National Laboratories Updated 9...
# 4    Source: Sandia National Laboratories Updated 9...
# ..                                                 ...
# 508  Source: Sandia National Laboratories Updated 9...
# 509  Source: Sandia National Laboratories Updated 9...
# 510  Source: Sandia National Laboratories Updated 9...
# 511  Source: Sandia National Laboratories Updated 9...
# 512  Source: Sandia National Laboratories Updated 9...
#
#                                          name  annual_energy_yield
# 0                  Advent_Solar_AS160___2006_        192282.329768
# 1            Advent_Solar_Ventura_210___2008_        226684.270326
# 2            Advent_Solar_Ventura_215___2009_        250480.349084
# 3                     Aleo_S03_160__2007__E__        186434.210499
# 4                     Aleo_S03_165__2007__E__        191864.045162
# ..                                        ...                  ...
# 508         Yingli_Solar_YL220_Module___2008_        242287.899650
# 509      Yingli_Solar_YL220_Module__2008__E__        255513.103641
# 510     Yingli_Solar_YL230_29b_Module___2009_        268803.884622
# 511  Yingli_Solar_YL230_29b_Module__2009__E__        269351.229827
# 512                   Yingli_YL210__2008__E__        247503.120780
#
# [513 rows x 45 columns]

# %% [markdown]
# # Area to annual energy, no other features

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

features = ['Area']

target = 'annual_energy_yield'

X_train, X_test, y_train, y_test = train_test_split(df[features], df[target], random_state=0, shuffle=True, test_size=0.2)

model = RandomForestRegressor()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

plt.scatter(X_test['Area'], y_test)
plt.scatter(X_test['Area'], y_pred, color='red')

print(metrics.r2_score(y_test, y_pred))
print(metrics.mean_absolute_percentage_error(y_test, y_pred))
print(metrics.mean_squared_error(y_test, y_pred))
# Out:
# 0.95351593536684
# 0.1481539488976269
# 436463478.22307366

# %% [markdown]
# # Straight forward all features

# %%
from sklearn import metrics
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

features = ['Area', 'Cells_in_Series',
       'Parallel_Strings', 'Isco', 'Voco', 'Impo', 'Vmpo', 'Aisc', 'Aimp',
       'C0', 'C1', 'Bvoco', 'Mbvoc', 'Bvmpo', 'Mbvmp', 'N', 'C2', 'C3', 'A0',
       'A1', 'A2', 'A3', 'A4', 'B0', 'B1', 'B2', 'B3', 'B4', 'B5', 'DTC', 'FD',
       'A', 'B', 'C4', 'C5', 'IXO', 'IXXO', 'C6', 'C7']

target = 'annual_energy_yield'

X_train, X_test, y_train, y_test = train_test_split(df[features], df[target], random_state=0, shuffle=True, test_size=0.2)

model = RandomForestRegressor()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

plt.scatter(X_test['Area'], y_test)
plt.scatter(X_test['Area'], y_pred, color='red')

print(metrics.r2_score(y_test, y_pred))
print(metrics.mean_absolute_percentage_error(y_test, y_pred))
print(metrics.mean_squared_error(y_test, y_pred))
# Out:
# 0.9899997200534719
# 0.05311803013662803
# 93897919.70886424

# %% [markdown]
# # Including materials

# %%
dfd = pandas.concat([df, pandas.get_dummies(df['Material']).astype(int)], axis=1)

# %%
from sklearn import metrics
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split


features = ['Area', 'Cells_in_Series',
       'Parallel_Strings', 'Isco', 'Voco', 'Impo', 'Vmpo', 'Aisc', 'Aimp',
       'C0', 'C1', 'Bvoco', 'Mbvoc', 'Bvmpo', 'Mbvmp', 'N', 'C2', 'C3', 'A0',
       'A1', 'A2', 'A3', 'A4', 'B0', 'B1', 'B2', 'B3', 'B4', 'B5', 'DTC', 'FD',
       'A', 'B', 'C4', 'C5', 'IXO', 'IXXO', 'C6', 'C7']
material_features = list(df['Material'].value_counts().index)

target = 'annual_energy_yield'

X_train, X_test, y_train, y_test = train_test_split(dfd[features + material_features], dfd[target], random_state=0, shuffle=True, test_size=0.2)

model = RandomForestRegressor()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

plt.scatter(X_test['Area'], y_test)
plt.scatter(X_test['Area'], y_pred, color='red')

print(metrics.r2_score(y_test, y_pred))
print(metrics.mean_absolute_percentage_error(y_test, y_pred))
print(metrics.mean_squared_error(y_test, y_pred))
# Out:
# 0.9899968176010463
# 0.05484862995789962
# 93925172.37041692

# %% [markdown]
# # Correlated features with materials

# %%
from sklearn import metrics
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split


features = ['Area', 'Isco', 'Voco', 'Impo', 'Vmpo', 'Cells_in_Series', 'IXO', 'IXXO', 'Bvoco', 'Bvmpo',]
#, 'Cells_in_Series', 'Parallel_Strings'
       #  , 'Aisc', 'Aimp',
       # 'C0', 'C1', 'Bvoco', 'Mbvoc', 'Bvmpo', 'Mbvmp', 'N', 'C2', 'C3', 'A0',
       # 'A1', 'A2', 'A3', 'A4', 'B0', 'B1', 'B2', 'B3', 'B4', 'B5', 'DTC', 'FD',
       # 'A', 'B', 'C4', 'C5',  'C6', 'C7'
material_features = list(df['Material'].value_counts().index)

target = 'annual_energy_yield'

X_train, X_test, y_train, y_test = train_test_split(dfd[features + material_features], dfd[target], random_state=0, shuffle=True, test_size=0.2)

model = RandomForestRegressor()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

plt.scatter(X_test['Area'], y_test)
plt.scatter(X_test['Area'], y_pred, color='red')

print(metrics.r2_score(y_test, y_pred))
print(metrics.mean_absolute_percentage_error(y_test, y_pred))
print(metrics.mean_squared_error(y_test, y_pred))
# Out:
# 0.9882489242918545
# 0.052830871890440396
# 110337067.48572642

# %% [markdown]
# # Also including vintage feature

# %%
from sklearn import metrics
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

dfd['Vintage'] = dfd['Vintage'].astype(str).apply(lambda x: x.replace('(E)', '').strip()).astype(int)

features = ['Area', 'Isco', 'Voco', 'Impo', 'Vmpo', 'Cells_in_Series', 'IXO', 'IXXO', 'Bvoco', 'Bvmpo', 'Vintage']
#, 'Cells_in_Series', 'Parallel_Strings'
       #  , 'Aisc', 'Aimp',
       # 'C0', 'C1', 'Bvoco', 'Mbvoc', 'Bvmpo', 'Mbvmp', 'N', 'C2', 'C3', 'A0',
       # 'A1', 'A2', 'A3', 'A4', 'B0', 'B1', 'B2', 'B3', 'B4', 'B5', 'DTC', 'FD',
       # 'A', 'B', 'C4', 'C5',  'C6', 'C7'
material_features = list(df['Material'].value_counts().index)

target = 'annual_energy_yield'

X_train, X_test, y_train, y_test = train_test_split(dfd[features + material_features], dfd[target], random_state=0, shuffle=True, test_size=0.2)

model = RandomForestRegressor()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

plt.scatter(X_test['Area'], y_test)
plt.scatter(X_test['Area'], y_pred, color='red')

print(metrics.r2_score(y_test, y_pred))
print(metrics.mean_absolute_percentage_error(y_test, y_pred))
print(metrics.mean_squared_error(y_test, y_pred))
# Out:
# 0.9818895735337037
# 0.053756415058165107
# 170048376.57729563

# %% [markdown]
# # Scaling

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn import metrics
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split


features = ['Area', 'Isco', 'Voco', 'Impo', 'Vmpo', 'Cells_in_Series', 'IXO', 'IXXO', 'Bvoco', 'Bvmpo']
#, 'Cells_in_Series', 'Parallel_Strings'
       #  , 'Aisc', 'Aimp',
       # 'C0', 'C1', 'Bvoco', 'Mbvoc', 'Bvmpo', 'Mbvmp', 'N', 'C2', 'C3', 'A0',
       # 'A1', 'A2', 'A3', 'A4', 'B0', 'B1', 'B2', 'B3', 'B4', 'B5', 'DTC', 'FD',
       # 'A', 'B', 'C4', 'C5',  'C6', 'C7'
material_features = list(df['Material'].value_counts().index)

target = 'annual_energy_yield'

X_train, X_test, y_train, y_test = train_test_split(dfd[features + material_features], dfd[target], random_state=0, shuffle=True, test_size=0.2)


scaler = MinMaxScaler()
linear_regression = RandomForestRegressor()
pipeline = Pipeline(
 [
     ("scaler", scaler),
     ("linear_regression", linear_regression),
 ]
)
pipeline.fit(X_train, y_train)

y_pred = pipeline.predict(X_test)

plt.scatter(X_test['Area'], y_test)
plt.scatter(X_test['Area'], y_pred, color='red')

print(metrics.r2_score(y_test, y_pred))
print(metrics.mean_absolute_percentage_error(y_test, y_pred))
print(metrics.mean_squared_error(y_test, y_pred))
# Out:
# 0.988880326648047
# 0.04991839248775317
# 104408496.67943215

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler, StandardScaler, PolynomialFeatures
from sklearn import metrics
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split


dfd['Vintage'] = dfd['Vintage'].astype(str).apply(lambda x: x.replace('(E)', '').strip()).astype(int)

features = ['Area', 'Isco', 'Voco', 'Impo', 'Vmpo', 'Cells_in_Series', 'IXO', 'IXXO', 'Bvoco', 'Bvmpo', 'Vintage']
#, 'Cells_in_Series', 'Parallel_Strings'
       #  , 'Aisc', 'Aimp',
       # 'C0', 'C1', 'Bvoco', 'Mbvoc', 'Bvmpo', 'Mbvmp', 'N', 'C2', 'C3', 'A0',
       # 'A1', 'A2', 'A3', 'A4', 'B0', 'B1', 'B2', 'B3', 'B4', 'B5', 'DTC', 'FD',
       # 'A', 'B', 'C4', 'C5',  'C6', 'C7'
material_features = list(df['Material'].value_counts().index[1:])

target = 'annual_energy_yield'

X_train, X_test, y_train, y_test = train_test_split(dfd[features + material_features], dfd[target], random_state=0, shuffle=True, test_size=0.2)


scaler = MinMaxScaler()
polynomial_features = PolynomialFeatures(degree=2, include_bias=False)
linear_regression = RandomForestRegressor()
pipeline = Pipeline(
 [
       ("scaler", scaler),
       ("polynomial_features", polynomial_features),
       ("linear_regression", linear_regression),
 ]
)
pipeline.fit(X_train, y_train)

y_pred = pipeline.predict(X_test)

plt.scatter(X_test['Area'], y_test)
plt.scatter(X_test['Area'], y_pred, color='red')

print(metrics.r2_score(y_test, y_pred))
print(metrics.mean_absolute_percentage_error(y_test, y_pred))
print(metrics.mean_squared_error(y_test, y_pred))
# Out:
# 0.9928888299715806
# 0.038238760876425346
# 66770538.01843076
